# %%
import pandas as pd

# %%
ind = pd.read_csv(r'C:\Users\analyst2.LCA\OneDrive - crescendoam.com\Desktop\Feb 2023\data\ind30_m_vw_rets.csv',header=0, index_col=0, parse_dates=True)/100

# %%
ind
# Out:
#           Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2018-08 -0.0038 -0.0186 -0.0543  0.0289 -0.0447  0.0254  0.0526  0.0446
# 2018-09 -0.0032  0.0019  0.0537 -0.0009 -0.0221  0.0107  0.0130  0.0199
# 2018-10  0.0102 -0.0157  0.0790 -0.1596 -0.0666 -0.0051 -0.1014 -0.0884
# 2018-11  0.0272  0.0579 -0.0843 -0.0065  0.0325  0.0644 -0.0099  0.0632
# 2018-12 -0.0973 -0.0969 -0.1580 -0.0824 -0.1535 -0.0557 -0.0728 -0.0840
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# ...

# %%
ind.index = pd.to_datetime(ind.index, format="%Y%m").to_period('M')

# %%
ind.columns = ind.columns.str.strip()

# %%
ind.columns
# Out:
# Index(['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other'],
#       dtype='object')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import Risk_Kit as erk

# %%
ind = erk.get_ind_returns()

# %%
ind
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2018-08 -0.0038 -0.0186 -0.0543  0.0289 -0.0447  0.0254  0.0526  0.0446
# 2018-09 -0.0032  0.0019  0.0537 -0.0009 -0.0221  0.0107  0.0130  0.0199
# 2018-10  0.0102 -0.0157  0.0790 -0.1596 -0.0666 -0.0051 -0.1014 -0.0884
# 2018-11  0.0272  0.0579 -0.0843 -0.0065  0.0325  0.0644 -0.0099  0.0632
# 2018-12 -0.0973 -0.0969 -0.1580 -0.0824 -0.1535 -0.0557 -0.0728 -0.0840
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# ...

# %%
erk.drawdown(ind['Food'])['Drawdown'].plot.line(figsize=(12,6), color = "#A2142F")
# Out:
# <AxesSubplot:>

# %%
erk.var_gaussian(ind[["Food","Smoke","Coal","Beer","Fin"]], modified = True)
# Out:
# Food     0.061207
# Smoke    0.080292
# Coal     0.047359
# Beer     0.033881
# Fin      0.075199
# dtype: float64

# %%
erk.var_gaussian(ind, modified = True).sort_values().tail()
# Out:
# Carry    0.094527
# Meals    0.098403
# BusEq    0.099377
# Games    0.100701
# Mines    0.102782
# dtype: float64

# %%
erk.var_gaussian(ind, modified = True).sort_values().head()
# Out:
# Beer     0.033881
# Coal     0.047359
# Food     0.061207
# Telcm    0.064719
# Hshld    0.064886
# dtype: float64

# %%
erk.var_gaussian(ind, modified = True).sort_values().plot.bar(color = "#A2142F")
# Out:
# <AxesSubplot:>

# %%
erk.sharp_ratio(ind, 0.03, 12).sort_values().plot.bar(title = "Industry Sharp Ratios 1926-2018", color = "#A2142F")
# Out:
# <AxesSubplot:title={'center':'Industry Sharp Ratios 1926-2018'}>

# %%
erk.sharp_ratio(ind["2000":], 0.03, 12).sort_values().plot.bar(title = "Industry Sharp Ratios 2000-2018", color = "#A2142F")
# Out:
# <AxesSubplot:title={'center':'Industry Sharp Ratios 2000-2018'}>

# %%
er = erk.annualized_rets(ind["1995":"2000"],12)

# %%
er.sort_values().plot.bar(color = "#A2142F")
# Out:
# <AxesSubplot:>

# %%
cov = ind["1995":"2000"].cov()

# %%
cov.shape
# Out:
# (30, 30)

# %%
cov
# Out:
#            Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# Food   0.002287  0.002077  0.001757  0.000701  0.000886  0.001208  0.001474
# Beer   0.002077  0.004599  0.001143  0.001147  0.000765  0.002447  0.001415
# Smoke  0.001757  0.001143  0.007130  0.000296 -0.000099  0.000981  0.000761
# Games  0.000701  0.001147  0.000296  0.003271  0.001485  0.001018  0.001814
# Books  0.000886  0.000765 -0.000099  0.001485  0.002302  0.000876  0.002037
# Hshld  0.001208  0.002447  0.000981  0.001018  0.000876  0.002849  0.001046
# Clths  0.001474  0.001415  0.000761  0.001814  0.002037  0.001046  0.004896
# Hlth   0.001105  0.001689  0.000877  0.001219  0.000657  0.001253  0.000759
# Chems  0.001253  0.001292  0.000687  0.001547  0.001559  0.001226  0.002547
# Txtls  0.001021  0.001721  0.000555  0.001291  0.001362  0.001172  0.002105
# Cnstr  0.001282  0.001945  0.001181  0.001723  0.001531  0.001770  0.002486
# ...
